# %%
import collections
import math
import os
import random

import numpy as np
import pandas as pd
import tensorflow as tf
import  nltk

# %%
l2 = np.load('./l2_embed3.npy')

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
mbatch = MiniBatchKMeans(n_clusters=1710, batch_size=3000, max_iter=100000)

# %%
centroids = mbatch.fit(l2[:,:-2])
# Out:
# /home/lenny/anaconda3/lib/python3.5/site-packages/sklearn/cluster/k_means_.py:1279: DeprecationWarning: This function is deprecated. Please call randint(0, 171042 + 1) instead
#   0, n_samples - 1, init_size)
# /home/lenny/anaconda3/lib/python3.5/site-packages/sklearn/cluster/k_means_.py:630: DeprecationWarning: This function is deprecated. Please call randint(0, 171042 + 1) instead
#   0, n_samples - 1, init_size)
# /home/lenny/anaconda3/lib/python3.5/site-packages/sklearn/cluster/k_means_.py:630: DeprecationWarning: This function is deprecated. Please call randint(0, 171042 + 1) instead
#   0, n_samples - 1, init_size)
# /home/lenny/anaconda3/lib/python3.5/site-packages/sklearn/cluster/k_means_.py:630: DeprecationWarning: This function is deprecated. Please call randint(0, 171042 + 1) instead
#   0, n_samples - 1, init_size)
# ...

# %%
np.save('./centroidsl2', centroids)
